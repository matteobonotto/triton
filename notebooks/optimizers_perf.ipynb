# %%
import os
# os.environ["TRITON_INTERPRET"] = "1"

import triton
import torch
from torch import Tensor, nn
from typing import Dict, Optional
from math import ceil
import numpy as np
from torch.autograd import Function
from torch.autograd.function import Function
from functools import partial
import math
from copy import deepcopy
import triton.language as tl
from triton.tools.tensor_descriptor import TensorDescriptor

from triton_kernels.optim.ops.rmsprop import rmsprop_interface, rmsprop_interface_torch

DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(DEVICE)
# Out:
# cuda

# %%
os.environ["TRITON_PRINT_AUTOTUNING"] = "1"

# %% [markdown]
# ## Adam

# %%
from triton_kernels.optim.ops.adam import adam_interface, adam_interface_torch

MAP_FUN = {
    # "torch" : partial(rmsprop_torch, implace = False),
    "torch" : partial(adam_interface_torch, implace = True),
    "triton" : adam_interface,
    # "triton" : rmsprop,
}

names = list(MAP_FUN.keys())
available_colors = ["black", "red", "green", "blue", "yellow", "cyan", "purple", "grey"]
colors = available_colors[:len(MAP_FUN)]

def is_cuda():
    return triton.runtime.driver.active.get_current_target().backend == "cuda"

ref_lib = 'cuBLAS' if is_cuda() else 'rocBLAS'
TORCH_HAS_FP8 = hasattr(torch, "float8_e5m2")

configs = []
for fp8_inputs in [True]:
    configs.append(
        triton.testing.Benchmark(
            x_names=["D"],  # Argument names to use as an x-axis for the plot
            x_vals=[int(2 ** i) for i in np.arange(5, 14, 1)],  # Different possible values for `x_name`
            line_arg="provider",  # Argument name whose value corresponds to a different line in the plot
            line_vals=names, #["triton"] if fp8_inputs else [ref_lib.lower(), "triton"],  # Label name for the lines
            line_names=names, #["Triton"] if fp8_inputs else [ref_lib, "Triton"],  # Line styles
            styles=[(x, "-") for x, _ in zip(colors,names)], # ("green", "-"), ("blue", "-")],
            ylabel="TFLOPS",  # Label name for the y-axis
            plot_name="gated-mlp-performance",  # Name for the plot, used also as a file name for saving the plot.
            args={"fp8_inputs": fp8_inputs},
        ))

@triton.testing.perf_report(configs)
def benchmark(D, provider, fp8_inputs):
    
    DTYPE = torch.float16
    print(f"{provider=}, {DTYPE=}, {D=},")
    
    param = torch.rand(D, D).to(DEVICE)
    grad = torch.rand(D, D).to(DEVICE) 
    exp_avg = torch.rand(D, D).to(DEVICE) 
    exp_avg_sq = torch.rand(D, D).to(DEVICE) 

    fun = MAP_FUN[provider]
    kwargs = {
        "param" : param,
        "grad" : grad,
        "exp_avg" : exp_avg,
        "exp_avg_sq" : exp_avg_sq,
        "step": 1., 
        "beta1" : 0.9,
        "beta2": 0.999,
    }
    quantiles = [0.5, 0.2, 0.8]
    ms, min_ms, max_ms = triton.testing.do_bench(lambda: fun(**kwargs), quantiles=quantiles) 
    perf = lambda ms: 9 * D * D * 1e-12 / (ms * 1e-3)
    return perf(ms), perf(max_ms), perf(min_ms)


df = benchmark.run(show_plots=True, print_data=True, return_df=True)[0]

df.plot.bar(x="D",ylabel="TFLOPS", xlabel="D")
# Out:
# provider='torch', DTYPE=torch.float16, D=32,
# provider='triton', DTYPE=torch.float16, D=32,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (1024, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 2.50s,
# best config selected: BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=64,
# provider='triton', DTYPE=torch.float16, D=64,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (4096, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 0.96s,
# best config selected: BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=128,
# provider='triton', DTYPE=torch.float16, D=128,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (16384, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 0.96s,
# best config selected: BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=256,
# provider='triton', DTYPE=torch.float16, D=256,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (65536, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 0.96s,
# best config selected: BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=512,
# provider='triton', DTYPE=torch.float16, D=512,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (262144, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 0.96s,
# best config selected: BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=1024,
# provider='triton', DTYPE=torch.float16, D=1024,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (1048576, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 0.97s,
# best config selected: BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=2048,
# provider='triton', DTYPE=torch.float16, D=2048,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (4194304, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 1.13s,
# best config selected: BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=4096,
# provider='triton', DTYPE=torch.float16, D=4096,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (16777216, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 1.36s,
# best config selected: BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# provider='torch', DTYPE=torch.float16, D=8192,
# provider='triton', DTYPE=torch.float16, D=8192,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 64, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 128, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 256, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 512, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 1024, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 2048, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 4096, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# Triton autotuning for function _adam_kernel,
# with key as (67108864, 'torch.float32', 'torch.float32', 'torch.float32', 'torch.float32'),
# finished after 2.22s,
# best config selected: BLOCK_SIZE: 32, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None;
# gated-mlp-performance:
#         D     torch    triton
# 0    32.0  0.000600  0.001800
# 1    64.0  0.002118  0.007089
# 2   128.0  0.007579  0.020571
# 3   256.0  0.023040  0.052364
# 4   512.0  0.042667  0.069818
# 5  1024.0  0.056807  0.069293
# 6  2048.0  0.050917  0.071860
# 7  4096.0  0.029319  0.077021
# 8  8192.0  0.029500  0.077364
# <Axes: xlabel='D', ylabel='TFLOPS'>

# %% [markdown]
# ## RMSprop

# %%
MAP_FUN = {
    # "torch" : partial(rmsprop_torch, implace = False),
    "torch" : partial(rmsprop_interface_torch, implace = True),
    "triton" : rmsprop_interface,
    # "triton" : rmsprop,
}

names = list(MAP_FUN.keys())
available_colors = ["black", "red", "green", "blue", "yellow", "cyan", "purple", "grey"]
colors = available_colors[:len(MAP_FUN)]

# %%
def is_cuda():
    return triton.runtime.driver.active.get_current_target().backend == "cuda"

ref_lib = 'cuBLAS' if is_cuda() else 'rocBLAS'
TORCH_HAS_FP8 = hasattr(torch, "float8_e5m2")

configs = []
for fp8_inputs in [True]:
    configs.append(
        triton.testing.Benchmark(
            x_names=["D"],  # Argument names to use as an x-axis for the plot
            x_vals=[int(2 ** i) for i in np.arange(5, 14, 1)],  # Different possible values for `x_name`
            line_arg="provider",  # Argument name whose value corresponds to a different line in the plot
            line_vals=names, #["triton"] if fp8_inputs else [ref_lib.lower(), "triton"],  # Label name for the lines
            line_names=names, #["Triton"] if fp8_inputs else [ref_lib, "Triton"],  # Line styles
            styles=[(x, "-") for x, _ in zip(colors,names)], # ("green", "-"), ("blue", "-")],
            ylabel="TFLOPS",  # Label name for the y-axis
            plot_name="gated-mlp-performance",  # Name for the plot, used also as a file name for saving the plot.
            args={"fp8_inputs": fp8_inputs},
        ))

@triton.testing.perf_report(configs)
def benchmark(D, provider, fp8_inputs):
    
    DTYPE = torch.float16
    print(f"{provider=}, {DTYPE=}, {D=},")
    
    param = torch.rand(D, D).to(DEVICE)
    grad = torch.rand(D, D).to(DEVICE) 
    square_avg = torch.rand(D, D).to(DEVICE) 

    fun = MAP_FUN[provider]
    kwargs = {
        "param" : param,
        "grad" : grad,
        "square_avg" : square_avg,
    }
    quantiles = [0.5, 0.2, 0.8]
    ms, min_ms, max_ms = triton.testing.do_bench(lambda: fun(**kwargs), quantiles=quantiles) 
    perf = lambda ms: 9 * D * D * 1e-12 / (ms * 1e-3)
    return perf(ms), perf(max_ms), perf(min_ms)


df = benchmark.run(show_plots=True, print_data=True, return_df=True)[0]

df.plot.bar(x="D",ylabel="TFLOPS", xlabel="D")
# Out:
# provider='torch', DTYPE=torch.float16, D=32,
# provider='triton', DTYPE=torch.float16, D=32,
# provider='torch', DTYPE=torch.float16, D=64,
# provider='triton', DTYPE=torch.float16, D=64,
# provider='torch', DTYPE=torch.float16, D=128,
# provider='triton', DTYPE=torch.float16, D=128,
# provider='torch', DTYPE=torch.float16, D=256,
# provider='triton', DTYPE=torch.float16, D=256,
# provider='torch', DTYPE=torch.float16, D=512,
# provider='triton', DTYPE=torch.float16, D=512,
# provider='torch', DTYPE=torch.float16, D=1024,
# provider='triton', DTYPE=torch.float16, D=1024,
# provider='torch', DTYPE=torch.float16, D=2048,
# provider='triton', DTYPE=torch.float16, D=2048,
# provider='torch', DTYPE=torch.float16, D=4096,
# provider='triton', DTYPE=torch.float16, D=4096,
# provider='torch', DTYPE=torch.float16, D=8192,
# provider='triton', DTYPE=torch.float16, D=8192,
# gated-mlp-performance:
#         D     torch    triton
# 0    32.0  0.000821  0.002241
# 1    64.0  0.002769  0.006000
# 2   128.0  0.009600  0.024000
# 3   256.0  0.026445  0.057600
# 4   512.0  0.059077  0.084842
# 5  1024.0  0.080139  0.105026
# 6  2048.0  0.076008  0.094489
# 7  4096.0  0.040577  0.105401
# 8  8192.0  0.041103  0.108543
# <Axes: xlabel='D', ylabel='TFLOPS'>

# %% [markdown]
# ## Adam

# %%
# Out:
# provider='torch', DTYPE=torch.float16, D=32,
# provider='triton', DTYPE=torch.float16, D=32,
# Autotuning kernel _adam_kernel with config BLOCK_SIZE: 16, num_warps: 4, num_ctas: 1, num_stages: 3, maxnreg: None
# ---------------------------------------------------------------------------
# CompilationError                          Traceback (most recent call last)
# Cell In[15], line 60
#      56     perf = lambda ms: 9 * D * D * 1e-12 / (ms * 1e-3)
#      57     return perf(ms), perf(max_ms), perf(min_ms)
# ---> 60 df = benchmark.run(show_plots=True, print_data=True, return_df=True)[0]
#      62 df.plot.bar(x="D",ylabel="TFLOPS", xlabel="D")
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/testing.py:392, in Mark.run(self, show_plots, print_data, save_path, return_df, **kwargs)
#     390 try:
#     391     for bench in benchmarks:
# --> 392         result_dfs.append(self._run(bench, save_path, show_plots, print_data, **kwargs))
#     393 finally:
#     394     if save_path:
#     395         # Create directory if it doesn't exist
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/testing.py:339, in Mark._run(self, bench, save_path, show_plots, print_data, diff_col, save_precision, **kwrags)
#     337 row_mean, row_min, row_max = [], [], []
#     338 for y in bench.line_vals:
# --> 339     ret = self.fn(**x_args, **{bench.line_arg: y}, **bench.args, **kwrags)
#     340     try:
#     341         y_mean, y_min, y_max = ret
#
# Cell In[15], line 55, in benchmark(D, provider, fp8_inputs)
#      47 kwargs = {
#      48     "param" : param,
#      49     "grad" : grad,
#    (...)     52     "step": 1.,
#      53 }
#      54 quantiles = [0.5, 0.2, 0.8]
# ---> 55 ms, min_ms, max_ms = triton.testing.do_bench(lambda: fun(**kwargs), quantiles=quantiles)
#      56 perf = lambda ms: 9 * D * D * 1e-12 / (ms * 1e-3)
#      57 return perf(ms), perf(max_ms), perf(min_ms)
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/testing.py:149, in do_bench(fn, warmup, rep, grad_to_none, quantiles, return_mode)
#     145 assert return_mode in ["min", "max", "mean", "median", "all"]
#     147 di = runtime.driver.active.get_device_interface()
# --> 149 fn()
#     150 di.synchronize()
#     152 cache = runtime.driver.active.get_empty_cache_for_benchmark()
#
# Cell In[15], line 55, in benchmark.<locals>.<lambda>()
#      47 kwargs = {
#      48     "param" : param,
#      49     "grad" : grad,
#    (...)     52     "step": 1.,
#      53 }
#      54 quantiles = [0.5, 0.2, 0.8]
# ---> 55 ms, min_ms, max_ms = triton.testing.do_bench(lambda: fun(**kwargs), quantiles=quantiles)
#      56 perf = lambda ms: 9 * D * D * 1e-12 / (ms * 1e-3)
#      57 return perf(ms), perf(max_ms), perf(min_ms)
#
# File ~/triton-kernels/src/triton_kernels/optim/ops/adam.py:168, in adam_interface(param, grad, exp_avg, exp_avg_sq, step, lr, beta1, beta2, eps)
#     163 grid = lambda META: (triton.cdiv(num_el, META["BLOCK_SIZE"]),)
#     165 # BLOCK_SIZE = 16
#     166 # grid = cdiv(num_el, BLOCK_SIZE) ,
# --> 168 _adam_kernel[grid](
#     169     param.view(-1),
#     170     exp_avg.view(-1),
#     171     exp_avg_sq.view(-1),
#     172     grad.view(-1),
#     173     float(step),
#     174     lr,
#     175     beta1,
#     176     beta2,
#     177     eps,
#     178     num_el,
#     179     # BLOCK_SIZE,
#     180 )
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/jit.py:419, in KernelInterface.__getitem__.<locals>.<lambda>(*args, **kwargs)
#     413 def __getitem__(self, grid) -> T:
#     414     """
#     415     A JIT function is launched with: fn[grid](*args, **kwargs).
#     416     Hence JITFunction.__getitem__ returns a callable proxy that
#     417     memorizes the grid.
#     418     """
# --> 419     return lambda *args, **kwargs: self.run(grid=grid, warmup=False, *args, **kwargs)
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/autotuner.py:238, in Autotuner.run(self, *args, **kwargs)
#     236             used_cached_result = self.check_disk_cache(key, pruned_configs, benchmark)
#     237         else:
# --> 238             benchmark()
#     240     config = self.cache[key]
#     241 else:
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/autotuner.py:227, in Autotuner.run.<locals>.benchmark()
#     225 def benchmark():
#     226     bench_start = time.time()
# --> 227     timings = {config: self._bench(*args, config=config, **kwargs) for config in pruned_configs}
#     228     bench_end = time.time()
#     229     self.bench_time = bench_end - bench_start
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/autotuner.py:227, in <dictcomp>(.0)
#     225 def benchmark():
#     226     bench_start = time.time()
# --> 227     timings = {config: self._bench(*args, config=config, **kwargs) for config in pruned_configs}
#     228     bench_end = time.time()
#     229     self.bench_time = bench_end - bench_start
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/autotuner.py:162, in Autotuner._bench(self, config, *args, **meta)
#     159     self.post_hook(full_nargs, exception=None)
#     161 try:
# --> 162     return self.do_bench(kernel_call, quantiles=(0.5, 0.2, 0.8))
#     163 except (OutOfResources, CompileTimeAssertionFailure, PTXASError) as e:
#     164     if verbose:
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/testing.py:149, in do_bench(fn, warmup, rep, grad_to_none, quantiles, return_mode)
#     145 assert return_mode in ["min", "max", "mean", "median", "all"]
#     147 di = runtime.driver.active.get_device_interface()
# --> 149 fn()
#     150 di.synchronize()
#     152 cache = runtime.driver.active.get_empty_cache_for_benchmark()
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/autotuner.py:148, in Autotuner._bench.<locals>.kernel_call()
#     146 self.pre_hook(full_nargs)
#     147 try:
# --> 148     self.fn.run(
#     149         *args,
#     150         **current,
#     151     )
#     152 except Exception as e:
#     153     try:
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/jit.py:733, in JITFunction.run(self, grid, warmup, *args, **kwargs)
#     729 if kernel is None:
#     730     options, signature, constexprs, attrs = self._pack_args(backend, kwargs, bound_args, specialization,
#     731                                                             options)
# --> 733     kernel = self._do_compile(key, signature, device, constexprs, options, attrs, warmup)
#     734     if kernel is None:
#     735         return None
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/runtime/jit.py:861, in JITFunction._do_compile(self, key, signature, device, constexprs, options, attrs, warmup)
#     859     kernel = async_mode.submit(cache_key, async_compile, finalize_compile)
#     860 else:
# --> 861     kernel = self.compile(src, target=target, options=options.__dict__)
#     862     kernel_cache[key] = kernel
#     863     self._call_hook(knobs.runtime.jit_post_compile_hook, key, signature, device, constexprs, options, [attrs],
#     864                     warmup)
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/compiler/compiler.py:300, in compile(src, target, options, _env_vars)
#     298 module_map = backend.get_module_map()
#     299 try:
# --> 300     module = src.make_ir(target, options, codegen_fns, module_map, context)
#     301 except Exception as e:
#     302     filter_traceback(e)
#
# File ~/triton-kernels/venv/lib/python3.11/site-packages/triton/compiler/compiler.py:80, in ASTSource.make_ir(self, target, options, codegen_fns, module_map, context)
#      78 def make_ir(self, target: GPUTarget, options, codegen_fns, module_map, context):
#      79     from .code_generator import ast_to_ttir
# ---> 80     return ast_to_ttir(self.fn, self, context=context, options=options, codegen_fns=codegen_fns,
#      81                        module_map=module_map)
#
# CompilationError: at 54:33:
#     )
#     grad = tl.load(
#         grad_ptr + offset,
#         mask=mask,
#         other=0.0,
#     )
#
#     ### do actual computation
#     exp_avg = beta1 * exp_avg + (1 - beta1) * grad
#     exp_avg_sq = beta2 * exp_avg_sq + (1 - beta2) * grad * grad
#
#     exp_avg_hat = exp_avg / (1 - beta1**step)
#                                  ^
# AttributeError("'tensor' object has no attribute '__pow__'")
